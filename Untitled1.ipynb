# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import math
import random
import os
import gym
from IPython.display import clear_output

# Hyper Parameters
STATE_DIM = 4
ACTION_DIM = 2
STEP = 2000
SAMPLE_NUMS = 30


class ActorNetwork(nn.Module):

    def __init__(self,input_size,hidden_size,action_size):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size,hidden_size)
        self.fc2 = nn.Linear(hidden_size,hidden_size)
        self.fc3 = nn.Linear(hidden_size,action_size)

    def forward(self,x):
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        out = F.log_softmax(self.fc3(out))
        return out

class ValueNetwork(nn.Module):

    def __init__(self,input_size,hidden_size,output_size):
        super(ValueNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size,hidden_size)
        self.fc2 = nn.Linear(hidden_size,hidden_size)
        self.fc3 = nn.Linear(hidden_size,output_size)

    def forward(self,x):
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        out = out.reshape(out.shape[0])
        return out

def roll_out(actor_network,task,sample_nums,value_network,init_state):
    #task.reset()
    states = []
    actions = []
    rewards = []
    is_done = False
    final_r = 0
    state = init_state

    for j in range(sample_nums):
        states.append(state)
        log_softmax_action = actor_network(Variable(torch.Tensor([state])))
        softmax_action = torch.exp(log_softmax_action)
        action = np.random.choice(ACTION_DIM,p=softmax_action.cpu().data.numpy()[0])
        one_hot_action = [int(k == action) for k in range(ACTION_DIM)]
        next_state,reward,done,_ = task.step(action)
        #fix_reward = -10 if done else 1
        actions.append(one_hot_action)
        rewards.append(reward)
        final_state = next_state
        state = next_state
        if done:
            is_done = True
            state = task.reset()
            break
    if not is_done:
        final_r = value_network(Variable(torch.Tensor([final_state]))).cpu().data.numpy()

    return states,actions,rewards,final_r,state

def discount_reward(r, gamma,final_r):
    discounted_r = np.zeros_like(r)
    running_add = final_r
    for t in reversed(range(0, len(r))):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

def main():
    # init a task generator for data fetching
    task = gym.make("CartPole-v0")
    init_state = task.reset()
    
    mean_rewards = []
    mean_loss_actor = []
    mean_loss_value = []

    # init value network
    value_network = ValueNetwork(input_size = STATE_DIM,hidden_size = 40,output_size = 1)
    value_network_optim = torch.optim.Adam(value_network.parameters(),lr=0.01)

    # init actor network
    actor_network = ActorNetwork(STATE_DIM,40,ACTION_DIM)
    actor_network_optim = torch.optim.Adam(actor_network.parameters(),lr = 0.01)

    steps =[]
    task_episodes =[]
    test_results =[]
    
    batch_loss_actor = []
    batch_loss_value = []

    for step in range(STEP):
        states,actions,rewards,final_r,current_state = roll_out(actor_network,task,SAMPLE_NUMS,value_network,init_state)
        init_state = current_state
        actions_var = Variable(torch.Tensor(actions).view(-1,ACTION_DIM))
        states_var = Variable(torch.Tensor(states).view(-1,STATE_DIM))

        # train actor network
        actor_network_optim.zero_grad()
        log_softmax_actions = actor_network(states_var)
        vs = value_network(states_var).detach()
        # calculate qs
        qs = Variable(torch.Tensor(discount_reward(rewards,0.99,final_r)))

        advantages = qs - vs
        actor_network_loss = - torch.mean(torch.sum(log_softmax_actions*actions_var,1)* advantages)
        actor_network_loss.backward()
        batch_loss_actor.append(actor_network_loss.detach().numpy())
        torch.nn.utils.clip_grad_norm(actor_network.parameters(),0.5)
        actor_network_optim.step()

        # train value network
        value_network_optim.zero_grad()
        target_values = qs
        values = value_network(states_var)
        criterion = nn.MSELoss()
        value_network_loss = criterion(values,target_values)
        batch_loss_value.append(value_network_loss.detach().numpy())
        value_network_loss.backward()
        torch.nn.utils.clip_grad_norm(value_network.parameters(),0.5)
        value_network_optim.step()

        # Testing
        if (step + 1) % 50== 0:
                result = 0
                test_task = gym.make("CartPole-v0")
                for test_epi in range(10):
                    state = test_task.reset()
                    for test_step in range(200):
                        softmax_action = torch.exp(actor_network(Variable(torch.Tensor([state]))))
                        #print(softmax_action.data)
                        action = np.argmax(softmax_action.data.numpy()[0])
                        next_state,reward,done,_ = test_task.step(action)
                        result += reward
                        state = next_state
                        if done:
                            break
                            
                mean_rewards.append(np.mean(result / 10.0))
                mean_loss_actor.append(np.mean(batch_loss_actor))
                mean_loss_value.append(np.mean(batch_loss_value))

                batch_loss_actor = []
                batch_loss_value = []

                clear_output(True)
                plt.figure(figsize=[20, 4])    
                plt.subplot(1, 3, 1)
                plt.title("mean reward per game")
                plt.plot(range(len(mean_rewards)), mean_rewards)
                plt.grid()

                plt.subplot(1, 3, 2)
                plt.title("actor loss")
                plt.plot(range(len(mean_loss_actor)), mean_loss_actor)
                plt.grid()

                plt.subplot(1, 3, 3)
                plt.title("value loss")
                plt.plot(range(len(mean_loss_value)), mean_loss_value)
                plt.grid()
                plt.show()
                steps.append(step+1)
                test_results.append(result/10)
main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-70687b88f13e> in <module>()
#     182                 steps.append(step+1)
#     183                 test_results.append(result/10)
# --> 184 main()
#
# <ipython-input-10-70687b88f13e> in main()
#     165                 clear_output(True)
#     166                 plt.figure(figsize=[20, 4])
# --> 167                 plt.subplot(1, 3, 1)
#     168                 plt.title("mean reward per game")
#     169                 plt.plot(range(len(mean_rewards)), mean_rewards)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     507
#     508         # this call may differ for non-sep axes, e.g., polar
# --> 509         self._init_axis()
#     510         if facecolor is None:
#     511             facecolor = rcParams['axes.facecolor']
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _init_axis(self)
#     617         self.xaxis = maxis.XAxis(self)
#     618         self.spines['bottom'].register_axis(self.xaxis)
# --> 619         self.spines['top'].register_axis(self.xaxis)
#     620         self.yaxis = maxis.YAxis(self)
#     621         self.spines['left'].register_axis(self.yaxis)
#
# ~\Anaconda3\lib\site-packages\matplotlib\spines.py in register_axis(self, axis)
#     171         self.axis = axis
#     172         if self.axis is not None:
# --> 173             self.axis.cla()
#     174         self.stale = True
#     175
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     804         self.label.set_text('')  # self.set_label_text would change isDefault_
#     805
# --> 806         self._set_scale('linear')
#     807
#     808         # Clear the callback registry for this axis, or it may "leak"
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     770     def _set_scale(self, value, **kwargs):
#     771         self._scale = mscale.scale_factory(value, self, **kwargs)
# --> 772         self._scale.set_default_locators_and_formatters(self)
#     773
#     774         self.isDefault_majloc = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\scale.py in set_default_locators_and_formatters(self, axis)
#      71         linear scaling.
#      72         """
# ---> 73         axis.set_major_locator(AutoLocator())
#      74         axis.set_major_formatter(ScalarFormatter())
#      75         axis.set_minor_formatter(NullFormatter())
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in __init__(self)
#    2493             nbins = 'auto'
#    2494             steps = [1, 2, 2.5, 5, 10]
# -> 2495         MaxNLocator.__init__(self, nbins=nbins, steps=steps)
#    2496
#    2497
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in __init__(self, *args, **kwargs)
#    1839                     "Keywords are required for all arguments except 'nbins'")
#    1840         self.set_params(**self.default_params)
# -> 1841         self.set_params(**kwargs)
#    1842
#    1843     @staticmethod
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in set_params(self, **kwargs)
#    1890             else:
#    1891                 self._steps = self._validate_steps(steps)
# -> 1892             self._extended_steps = self._staircase(self._steps)
#    1893         if 'integer' in kwargs:
#    1894             self._integer = kwargs['integer']
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in _staircase(steps)
#    1866         # than necessary.
#    1867         flights = (0.1 * steps[:-1], steps, 10 * steps[1])
# -> 1868         return np.hstack(flights)
#    1869
#    1870     def set_params(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     284     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     285     if arrs and arrs[0].ndim == 1:
# --> 286         return _nx.concatenate(arrs, 0)
#     287     else:
#     288         return _nx.concatenate(arrs, 1)
#
# KeyboardInterrupt:
